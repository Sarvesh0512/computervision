# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirement
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 325 (delta 158), reused 155 (delta 155), pack-reused 109
# Receiving objects: 100% (325/325), 2.23 MiB | 15.05 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9/yolov9

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !pip install -q roboflow

# %%
# !ls -la {HOME}/weights
# Out:
# total 402448
# drwxr-xr-x 2 root root      4096 May 11 06:33 .
# drwxr-xr-x 3 root root      4096 May 11 06:33 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source /content/beetle.jpeg --device 0
# Out:
# detect: weights=['{HOME}/weights/gelan-c.pt'], source=/content/beetle.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients
# image 1/1 /content/beetle.jpeg: 448x640 1 car, 112.7ms
# Speed: 0.5ms pre-process, 112.7ms inference, 504.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
from IPython.display import Image
Image(filename=f"/content/yolov9/yolov9/runs/detect/exp2/beetle.jpeg",)

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source /content/avengers.jpg  --device 0
# Out:
# detect: weights=['{HOME}/weights/gelan-c.pt'], source=/content/avengers.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients
# image 1/1 /content/avengers.jpg: 384x640 7 persons, 117.6ms
# Speed: 0.6ms pre-process, 117.6ms inference, 506.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
from IPython.display import Image
Image(filename=f"/content/yolov9/yolov9/runs/detect/exp3/avengers.jpg",)

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source /content/kumki.jpg --device 0
# Out:
# detect: weights=['{HOME}/weights/gelan-c.pt'], source=/content/kumki.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients
# image 1/1 /content/kumki.jpg: 480x640 2 persons, 1 elephant, 184.1ms
# Speed: 0.6ms pre-process, 184.1ms inference, 899.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
from IPython.display import Image
Image(filename=f"/content/yolov9/yolov9/runs/detect/exp4/kumki.jpg",)

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source /content/har.jpg --device 0
# Out:
# detect: weights=['{HOME}/weights/gelan-c.pt'], source=/content/har.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients
# image 1/1 /content/har.jpg: 384x640 6 persons, 1 backpack, 1 handbag, 123.8ms
# Speed: 0.5ms pre-process, 123.8ms inference, 506.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
from IPython.display import Image
Image(filename=f"/content/yolov9/yolov9/runs/detect/exp5/har.jpg",)

# %%
# %pip install openimages
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 50.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 13.9 MB/s eta 0:00:00
# ...

# %%
from openimages.download import download_dataset
download_dataset(".data",["Elephant"],limit=20,annotation_format='pascal')
# Out:
# ...
# 100%|██████████| 20/20 [00:00<00:00, 926.36it/s]
# {'elephant': {'images_dir': '.data/elephant/images',
#   'annotations_dir': '.data/elephant/pascal'}}
